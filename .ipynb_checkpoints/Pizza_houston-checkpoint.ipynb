# %%
import json
import requests
import pandas as pd
from pprint import pprint
from pandas.io.json import json_normalize
import numpy as np

# %%
api_key='Vt-PaVFa5nzWAL0BEWsdKwhF1bOdFaWh_Bdb-SCFa0xjWQ6Yo8pF29crLXs3TzbFp3p_5WLEX4LlHxGjI9Mxu7yKlcSxXMndQDKeld5hctdkJ57tFVgg7Bwn5baXXXYx'
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
url='https://api.yelp.com/v3/businesses/search'
#params={'term':'bookstore', 'location':'New York City','limit':''}

# %%
# Assign Params
params = {'term':'italian','location':'Houston','limit':'50'}

# %%
# Making a get request to the API
req=requests.get(url, params=params, headers=headers)

# %%
req.json()
# Out:
# {'businesses': [{'id': 'd6cm5ns_Hfy83-e3nm3CSg',
#    'alias': 'rivas-italian-restaurant-houston',
#    'name': "Riva's Italian Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i-0pXB2oDMCetLeDiqNySg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rivas-italian-restaurant-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 508,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.74605, 'longitude': -95.39248},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1117 Missouri St',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77006',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1117 Missouri St', 'Houston, TX 77006']},
#    'phone': '+17135293450',
#    'display_phone': '(713) 529-3450',
#    'distance': 3668.962694214326},
#   {'id': 'x4WealiPVG-tzwzhe7nvpw',
#    'alias': 'north-italia-houston',
#    'name': 'North Italia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dsUzts2x9Ee9a_hjAbDzlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/north-italia-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 1500,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.7485868638914,
#     'longitude': -95.4620253208921},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1700 Post Oak Blvd',
#     'address2': 'Ste 190',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77056',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1700 Post Oak Blvd', 'Ste 190', 'Houston, TX 77056']},
#    'phone': '+12816054030',
#    'display_phone': '(281) 605-4030',
#    'distance': 9983.179390848347},
#   {'id': 'McwaN30rgpfIpyDPT913Vw',
#    'alias': 'fabios-artisan-pasta-houston',
#    'name': "Fabio's Artisan Pasta",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UL5j4JwdiZWek6ho0gFl5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fabios-artisan-pasta-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 244,
#    'categories': [{'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 29.73823, 'longitude': -95.41208},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2129 W Alabama St',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77098',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2129 W Alabama St', 'Houston, TX 77098']},
#    'phone': '+17135281329',
#    'display_phone': '(713) 528-1329',
#    'distance': 5740.851256560756},
#   {'id': 'gid41dFmk4cnSsy2OeJzEQ',
#    'alias': 'roma-houston',
#    'name': 'Roma',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZVHEkng8PAUf8rqGDTQDGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roma-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 66,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.7149, 'longitude': -95.41475},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2347 University Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77005',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2347 University Blvd', 'Houston, TX 77005']},
#    'phone': '+17136647581',
#    'display_phone': '(713) 664-7581',
#    'distance': 7521.471373663317},
#   {'id': 'z0sbzv4MRstpyodVBjCLLA',
#    'alias': 'coltivare-houston',
#    'name': 'Coltivare',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uTmBUm-ykxkXGFSG5rcJgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coltivare-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 815,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.7817, 'longitude': -95.39371},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3320 White Oak Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77007',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3320 White Oak Dr', 'Houston, TX 77007']},
#    'phone': '+17136374095',
#    'display_phone': '(713) 637-4095',
#    'distance': 3863.439668367201},
#   {'id': '8ZhYOX0zREv0Px2aBqnLNg',
#    'alias': 'mia-bella-trattoria-houston-14',
#    'name': 'Mia Bella Trattoria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7i_Om_o5DIKUUDblkjp1Eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mia-bella-trattoria-houston-14?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 352,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.7323697055943,
#     'longitude': -95.4381511442779},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3773 Richmond Ave',
#     'address2': 'Ste 1A',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77046',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3773 Richmond Ave', 'Ste 1A', 'Houston, TX 77046']},
#    'phone': '+17133937340',
#    'display_phone': '(713) 393-7340',
#    'distance': 8283.11301121304},
#   {'id': 'yTnMkgBS19T90hxWOEOy4A',
#    'alias': 'potente-houston',
#    'name': 'Potente',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/43_PXR28bztszl17c8aqFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/potente-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 197,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.7572378866031,
#     'longitude': -95.3574474900742},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1515 Texas Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77002',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1515 Texas Ave', 'Houston, TX 77002']},
#    'phone': '+17132371515',
#    'display_phone': '(713) 237-1515',
#    'distance': 687.5788988102834},
#   {'id': 'CoonE0BMUPRGHqXWj-XzxQ',
#    'alias': 'lomontes-italian-restaurant-and-bar-houston',
#    'name': "Lomonte's Italian Restaurant and Bar",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Zm6mZ9Tbdyn12YH3bR0vuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lomontes-italian-restaurant-and-bar-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 172,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.7827472686768,
#     'longitude': -95.642463684082},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '14510 Grisby Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77079',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['14510 Grisby Rd', 'Houston, TX 77079']},
#    'phone': '+12814960030',
#    'display_phone': '(281) 496-0030',
#    'distance': 27347.798690425236},
#   {'id': 'xRfw_M1BdMpnEzMcFCY_7g',
#    'alias': 'perbacco-houston',
#    'name': 'Perbacco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4IKxkwbpZ5enzKkWG-1v4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/perbacco-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 166,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.760168, 'longitude': -95.365059},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '700 Milam St',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77002',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['700 Milam St', 'Houston, TX 77002']},
#    'phone': '+17132242422',
#    'display_phone': '(713) 224-2422',
#    'distance': 586.2755486167018},
#   {'id': 'MXLhzFh9WK0ig3MYt5THDA',
#    'alias': 'grotto-downtown-houston',
#    'name': 'Grotto Downtown',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SLpcg8B8EVQy2RYuwly_Rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grotto-downtown-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 317,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.7539178, 'longitude': -95.3571966},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1001 Avenida De Las Americas',
#     'address2': 'Ste A',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77010',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1001 Avenida De Las Americas',
#      'Ste A',
#      'Houston, TX 77010']},
#    'phone': '+17136580752',
#    'display_phone': '(713) 658-0752',
#    'distance': 1047.1634280320973},
#   {'id': 'm-2gMLGy4vIufoL6QNy0tA',
#    'alias': 'giacomos-cibo-e-vino-houston',
#    'name': "Giacomo's Cibo e Vino",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ru_kIYaO3h5saIReja2OyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giacomos-cibo-e-vino-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 497,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.742032, 'longitude': -95.423718},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3215 Westheimer Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77098',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3215 Westheimer Rd', 'Houston, TX 77098']},
#    'phone': '+17135221934',
#    'display_phone': '(713) 522-1934',
#    'distance': 6583.267811896613},
#   {'id': 'SYnPb42JQ1zhERBEGg0sGg',
#    'alias': 'patrenellas-houston',
#    'name': "Patrenella's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iHgX93CCgM3Uba3NrSe5cg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patrenellas-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 346,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.76912, 'longitude': -95.4021},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '813 Jackson Hill St',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77007',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['813 Jackson Hill St', 'Houston, TX 77007']},
#    'phone': '+17138638223',
#    'display_phone': '(713) 863-8223',
#    'distance': 4122.1756837785115},
#   {'id': '0wemURLMYj9YkkXJI2aS6w',
#    'alias': 'paulies-houston',
#    'name': "Paulie's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vJfIhDcLieMU2RCDakbCyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paulies-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 773,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.7428749, 'longitude': -95.4064275},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1834 Westheimer Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77098',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1834 Westheimer Rd', 'Houston, TX 77098']},
#    'phone': '+17138077271',
#    'display_phone': '(713) 807-7271',
#    'distance': 4986.074028178806},
#   {'id': 'm15OdfXB2MFz_wdshwoGUA',
#    'alias': 'amalfi-ristorante-italiano-and-bar-houston',
#    'name': 'Amalfi Ristorante Italiano & Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hDjLC1TCui2eotSDltjRUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amalfi-ristorante-italiano-and-bar-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 179,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.7389991526496,
#     'longitude': -95.4903902865082},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '6100 Westheimer Rd',
#     'address2': 'Ste 140',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77057',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['6100 Westheimer Rd', 'Ste 140', 'Houston, TX 77057']},
#    'phone': '+17135322201',
#    'display_phone': '(713) 532-2201',
#    'distance': 12872.303065818098},
#   {'id': 'zYymsWEVEy02KA2KES1faw',
#    'alias': 'antica-osteria-houston',
#    'name': 'Antica Osteria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Our8CvTt5I0CK4VmBhvwLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/antica-osteria-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 310,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.725282, 'longitude': -95.413276},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '2311 Bissonnet St',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77005',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2311 Bissonnet St', 'Houston, TX 77005']},
#    'phone': '+17135211155',
#    'display_phone': '(713) 521-1155',
#    'distance': 6650.585570400708},
#   {'id': 'OYiE24uzI_YKGuchV8xo0Q',
#    'alias': 'piola-houston-7',
#    'name': 'Piola',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lA_bymUX7rw8NkaWySN8-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piola-houston-7?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 580,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.74287233551, 'longitude': -95.3798845184326},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3201 Louisiana St',
#     'address2': 'Ste 103',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77006',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3201 Louisiana St', 'Ste 103', 'Houston, TX 77006']},
#    'phone': '+17135248222',
#    'display_phone': '(713) 524-8222',
#    'distance': 2953.5375004870257},
#   {'id': '1oPxBD7nBPa8I6ZCeX1Svg',
#    'alias': 'damians-cucina-italiana-houston-2',
#    'name': "Damian's Cucina Italiana",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/orJx9X2KZr_06svB_gKH9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/damians-cucina-italiana-houston-2?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 211,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.74437, 'longitude': -95.3797},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '3011 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77006',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3011 Smith St', 'Houston, TX 77006']},
#    'phone': '+17135220439',
#    'display_phone': '(713) 522-0439',
#    'distance': 2818.0064561572626},
#   {'id': 'z1J0lVDuy7X7g9Xeha3jKg',
#    'alias': 'd-amicos-italian-market-cafe-houston',
#    'name': "D'Amico's Italian Market Cafe",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6ef3pwmPHDJPlIdxGigFUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/d-amicos-italian-market-cafe-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 356,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.71598, 'longitude': -95.4153504},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '5510 Morningside Dr',
#     'address2': 'Ste 140',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77005',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['5510 Morningside Dr',
#      'Ste 140',
#      'Houston, TX 77005']},
#    'phone': '+17135263400',
#    'display_phone': '(713) 526-3400',
#    'distance': 7481.392282281001},
#   {'id': 'KDkl-gEvbOyEYzuI6JNAlA',
#    'alias': 'mandolas-deli-houston',
#    'name': "Mandola's Deli",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZPLNAtBYjGy2Joni1poyvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mandolas-deli-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 269,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.73764, 'longitude': -95.33956},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '4105 Leeland St',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77023',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['4105 Leeland St', 'Houston, TX 77023']},
#    'phone': '+17132235186',
#    'display_phone': '(713) 223-5186',
#    'distance': 3458.0852592453975},
#   {'id': 'yCxdQ2cmsL9k7ktP9g5s4w',
#    'alias': 'bellissimo-ristorante-houston-2',
#    'name': 'Bellissimo Ristorante',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/w-Ip8KSDIDasw2AFn9lUlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bellissimo-ristorante-houston-2?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 209,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.804596, 'longitude': -95.381574},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1848 Airline Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77009',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1848 Airline Dr', 'Houston, TX 77009']},
#    'phone': '+18326181168',
#    'display_phone': '(832) 618-1168',
#    'distance': 5071.45470534417},
#   {'id': 'KJQu5oYl_x96aP4GLfWTgw',
#    'alias': 'dolce-vita-houston',
#    'name': 'Dolce Vita',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ItTAK5MvCwvdAlvATU8pEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dolce-vita-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 712,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.744775, 'longitude': -95.38742},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '500 Westheimer Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77006',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['500 Westheimer Rd', 'Houston, TX 77006']},
#    'phone': '+17135208222',
#    'display_phone': '(713) 520-8222',
#    'distance': 3340.9698648875833},
#   {'id': 'XPdL-df73m-sYrTndOrb3Q',
#    'alias': 'osso-and-kristalla-houston-2',
#    'name': 'Osso & Kristalla',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hCLkoyHtaMh1uubxwkdn9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osso-and-kristalla-houston-2?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 234,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.7574509, 'longitude': -95.3579026},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1515 Texas Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77002',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1515 Texas Ave', 'Houston, TX 77002']},
#    'phone': '+17132216666',
#    'display_phone': '(713) 221-6666',
#    'distance': 650.7708380567746},
#   {'id': '2uSi_8-xouauhoWadGFJfQ',
#    'alias': 'roccos-houston',
#    'name': "Rocco's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/obug8WIcSwbyldgDZ0jRXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roccos-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 55,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.79333, 'longitude': -95.35928},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '811 Collingsworth St',
#     'address2': None,
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77009',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['811 Collingsworth St', 'Houston, TX 77009']},
#    'phone': '+17133802700',
#    'display_phone': '(713) 380-2700',
#    'distance': 3371.9606766988},
#   {'id': '6eiWLIo58e4q1pOt_p6FXQ',
#    'alias': 'sorrento-ristorante-italiano-houston',
#    'name': 'Sorrento Ristorante Italiano',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mvyG964EuhJ7MMUkWlkjrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sorrento-ristorante-italiano-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 302,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.7444128, 'longitude': -95.3867141},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '415 Westheimer Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77006',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['415 Westheimer Rd', 'Houston, TX 77006']},
#    'phone': '+17135270609',
#    'display_phone': '(713) 527-0609',
#    'distance': 3332.9312824588856},
#   {'id': '_4O57SAgWtUafcBT4ruWSw',
#    'alias': 'grazia-italian-kitchen-pearland',
#    'name': 'Grazia Italian Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ikFXUFRYl2rixdBCzdGwTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grazia-italian-kitchen-pearland?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 756,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.5590781202424,
#     'longitude': -95.3657707648061},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '9415 Broadway',
#     'address2': 'Ste 103',
#     'address3': '',
#     'city': 'Pearland',
#     'zip_code': '77584',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['9415 Broadway', 'Ste 103', 'Pearland, TX 77584']},
#    'phone': '+18322308873',
#    'display_phone': '(832) 230-8873',
#    'distance': 22684.870006518682},
#   {'id': '0gvTBshm7gAq0sB53H-z0g',
#    'alias': 'carrabbas-the-original-on-kirby-houston-2',
#    'name': "Carrabba's - The Original on Kirby",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/z1brhVqR53bV_yC2YDjghQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carrabbas-the-original-on-kirby-houston-2?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 442,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.7364881579311,
#     'longitude': -95.4183509045328},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3115 Kirby Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77098',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3115 Kirby Dr', 'Houston, TX 77098']},
#    'phone': '+17135223131',
#    'display_phone': '(713) 522-3131',
#    'distance': 6363.1037974552655},
#   {'id': 'sQz8sc02VCw9yCEGwAGgPA',
#    'alias': 'georges-pastaria-houston',
#    'name': "George's Pastaria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EE0TDBwqlz62IAVyX_XtEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/georges-pastaria-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 231,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.74936, 'longitude': -95.60649},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1722 S Dairy Ashford St',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77077',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1722 S Dairy Ashford St', 'Houston, TX 77077']},
#    'phone': '+12815581717',
#    'display_phone': '(281) 558-1717',
#    'distance': 23855.524074164405},
#   {'id': 'YkB4ZffQBnpEljGZAX7xFA',
#    'alias': 'mia-bella-trattoria-houston-13',
#    'name': 'Mia Bella Trattoria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wU1Yn3-7JfKhGNst47-Vpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mia-bella-trattoria-houston-13?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 279,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.7534684960069,
#     'longitude': -95.3641167312134},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1201 Caroline St',
#     'address2': 'Ste 161',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77002',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1201 Caroline St', 'Ste 161', 'Houston, TX 77002']},
#    'phone': '+18323196675',
#    'display_phone': '(832) 319-6675',
#    'distance': 1136.1141742819455},
#   {'id': 'X8pydxs5EFUSwKDmhJCCEw',
#    'alias': 'grazia-italian-kitchen-houston',
#    'name': 'Grazia Italian Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/e4HBKO3bqAYAWp1DUa5GUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grazia-italian-kitchen-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 229,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.5777702331543,
#     'longitude': -95.1404571533203},
#    'transactions': ['restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1001 Pineloch Dr',
#     'address2': 'Ste 1100',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77062',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1001 Pineloch Dr', 'Ste 1100', 'Houston, TX 77062']},
#    'phone': '+12814862083',
#    'display_phone': '(281) 486-2083',
#    'distance': 29556.687072125613},
#   {'id': '8dkNhXi6vPkZDgq7T0-xhg',
#    'alias': 'postino-montrose-houston-2',
#    'name': 'Postino Montrose',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5ZIrVBqRis7Y7lt-ZkCngg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/postino-montrose-houston-2?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 9,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 29.74651, 'longitude': -95.39033},
#    'transactions': [],
#    'location': {'address1': '805 Pacific St',
#     'address2': '',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77006',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['805 Pacific St', 'Houston, TX 77006']},
#    'phone': '+17133886767',
#    'display_phone': '(713) 388-6767',
#    'distance': 3455.361143026402},
#   {'id': 'vVxrh4Jf6Cq_-PKg8YObFg',
#    'alias': 'cavatore-italian-restaurant-houston',
#    'name': 'Cavatore Italian Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hAS92RXwkxQlZgDWW4FsFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cavatore-italian-restaurant-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 338,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 29.8052, 'longitude': -95.42883},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '2120 Ella Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77008',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2120 Ella Blvd', 'Houston, TX 77008']},
#    'phone': '+17138696622',
#    'display_phone': '(713) 869-6622',
#    'distance': 8120.842538541184},
#   {'id': 'QrrOqwS-oXJ3-CRQdusfBg',
#    'alias': 'boh-pasta-and-pizza-houston',
#    'name': 'BOH Pasta & Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2HSh_DRwZ3hLp0UGZsnplg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boh-pasta-and-pizza-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 26,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.7617656683504,
#     'longitude': -95.3621810104161},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '409 Travis St',
#     'address2': None,
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77002',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['409 Travis St', 'Houston, TX 77002']},
#    'phone': '+17133645502',
#    'display_phone': '(713) 364-5502',
#    'distance': 256.52692447637577},
#   {'id': 'QxzCY8B1N_XuIuUl-UanUA',
#    'alias': 'bollo-woodfired-pizza-houston',
#    'name': 'Bollo Woodfired Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KwuCTyhZQJMvW2-fiqT7TQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bollo-woodfired-pizza-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 569,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.7389786, 'longitude': -95.4134581},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2202 W Alabama St',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77098',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2202 W Alabama St', 'Houston, TX 77098']},
#    'phone': '+17136770391',
#    'display_phone': '(713) 677-0391',
#    'distance': 5816.198148890635},
#   {'id': 'ayPSl6UmabxlEXeHX8Fisw',
#    'alias': 'postino-heights-houston-3',
#    'name': 'Postino Heights',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YXZclCARt6Xj_oQPtlQHrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/postino-heights-houston-3?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 387,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.78306, 'longitude': -95.3985299},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '642 Yale St',
#     'address2': 'Ste A',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77007',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['642 Yale St', 'Ste A', 'Houston, TX 77007']},
#    'phone': '+13462231111',
#    'display_phone': '(346) 223-1111',
#    'distance': 4333.948852417317},
#   {'id': '8tk2n3wdXX3oq8lryKfeig',
#    'alias': 'frenchies-houston-3',
#    'name': "Frenchie's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BxptVhCwFrNF0RiXnq9Xmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frenchies-houston-3?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 271,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.5463748, 'longitude': -95.1058725},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1041 Nasa Pkwy',
#     'address2': None,
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77058',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1041 Nasa Pkwy', 'Houston, TX 77058']},
#    'phone': '+12814867144',
#    'display_phone': '(281) 486-7144',
#    'distance': 34391.835822245426},
#   {'id': 'ZkM_qfaCNWRCb0vb3T813g',
#    'alias': 'fresco-cafe-italiano-houston',
#    'name': 'Fresco Cafe Italiano',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WVxRS5Tf4PoFr2v7AlOY1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresco-cafe-italiano-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 170,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.7287262957213,
#     'longitude': -95.4316117488783},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3277 Southwest Fwy',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77027',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3277 Southwest Fwy', 'Ste A', 'Houston, TX 77027']},
#    'phone': '+12818882226',
#    'display_phone': '(281) 888-2226',
#    'distance': 7899.648765803011},
#   {'id': 'hBDyMM7g3Gy3ucKgLPUvZg',
#    'alias': 'adriatic-cafe-italian-grill-jersey-village',
#    'name': 'Adriatic Cafe  Italian Grill',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/oz5rZdxkq3ONgqorfL6Suw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/adriatic-cafe-italian-grill-jersey-village?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 521,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.8898572957493,
#     'longitude': -95.5826705374774},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '17402 Northwest Fwy',
#     'address2': None,
#     'address3': '',
#     'city': 'Jersey Village',
#     'zip_code': '77040',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['17402 Northwest Fwy', 'Jersey Village, TX 77040']},
#    'phone': '+17139836565',
#    'display_phone': '(713) 983-6565',
#    'distance': 25699.67299989509},
#   {'id': '52D7I26xY3t9uz0HgCBeGQ',
#    'alias': 'piada-italian-street-food-houston-2',
#    'name': 'Piada Italian Street Food',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fexn75FnuH5A6Ai3Jgsxqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piada-italian-street-food-houston-2?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 362,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.76099, 'longitude': -95.42052},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '5801 Memorial Dr',
#     'address2': 'Ste E',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77007',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['5801 Memorial Dr', 'Ste E', 'Houston, TX 77007']},
#    'phone': '+18328346415',
#    'display_phone': '(832) 834-6415',
#    'distance': 5841.586159494749},
#   {'id': 'bY7wa6sfVb7MKsxq8_pcVw',
#    'alias': 'vinoteca-poscol-houston-3',
#    'name': 'Vinoteca Poscol',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/R8BTqoTCcz_t4ZculR7GGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vinoteca-poscol-houston-3?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 117,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.74476, 'longitude': -95.3893499},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '608 Westheimer Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77006',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['608 Westheimer Rd', 'Houston, TX 77006']},
#    'phone': '+17135292797',
#    'display_phone': '(713) 529-2797',
#    'distance': 3485.306811663798},
#   {'id': 'N4TDKKat3ADCTWPGVmiEOA',
#    'alias': 'mina-ristorante-houston-2',
#    'name': 'Mina Ristorante',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WiG9IX6-HaHQXPyrGdD3Ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mina-ristorante-houston-2?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 9,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.7381940494014,
#     'longitude': -95.4363139242039},
#    'transactions': [],
#    'location': {'address1': '3641 W Alabama St',
#     'address2': '',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77027',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['3641 W Alabama St', 'Houston, TX 77027']},
#    'phone': '+18329402126',
#    'display_phone': '(832) 940-2126',
#    'distance': 7871.748562723768},
#   {'id': '-HLVm44tvKu2V31lz6VQaA',
#    'alias': 'maggianos-little-italy-houston',
#    'name': "Maggiano's Little Italy",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zwcGxO0AYTd_HHNrG-kS5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maggianos-little-italy-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 630,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 29.74507, 'longitude': -95.460509},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '2019 Post Oak Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77056',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2019 Post Oak Blvd', 'Houston, TX 77056']},
#    'phone': '+17139612700',
#    'display_phone': '(713) 961-2700',
#    'distance': 9910.23091617366},
#   {'id': '_WpiWEiXec2HsBaCDemq9Q',
#    'alias': 'lomontes-italian-restaurant-and-pizzeria-richmond-3',
#    'name': "Lomonte's Italian Restaurant & Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5IKnas3HO01fY-mIROd2YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lomontes-italian-restaurant-and-pizzeria-richmond-3?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 265,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.62409, 'longitude': -95.71922},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '815 Plantation Dr',
#     'address2': 'Ste 180',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': '77406',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['815 Plantation Dr', 'Ste 180', 'Richmond, TX 77406']},
#    'phone': '+12812328290',
#    'display_phone': '(281) 232-8290',
#    'distance': 37844.43965855639},
#   {'id': 'Eww0CBzbPPPAqVeLnKj5Pg',
#    'alias': 'spaghetti-western-italian-cafe-houston',
#    'name': 'Spaghetti Western Italian Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/43lWTm3vMhMT-yckN3H6EQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spaghetti-western-italian-cafe-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 274,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.775061, 'longitude': -95.409362},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1608 Shepherd Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77007',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1608 Shepherd Dr', 'Houston, TX 77007']},
#    'phone': '+17138611313',
#    'display_phone': '(713) 861-1313',
#    'distance': 4953.040992892985},
#   {'id': 'fZsyLhNQ0GvtKFzCKxS7Yg',
#    'alias': 'crisp-houston-2',
#    'name': 'Crisp',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r3VXcR8lruk7-fTWQTcJwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crisp-houston-2?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 845,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.8062839508057,
#     'longitude': -95.4220886230469},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2220 Bevis St',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77008',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2220 Bevis St', 'Houston, TX 77008']},
#    'phone': '+17133600222',
#    'display_phone': '(713) 360-0222',
#    'distance': 7687.150562772566},
#   {'id': 'ns0zrAgnlOmBh-AQUapBxg',
#    'alias': 'da-marco-houston',
#    'name': 'Da Marco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/k_0tX6Bg1zwkoSOJzmc40w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-marco-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 324,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.74313, 'longitude': -95.397814},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '1520 Westheimer Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77006',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['1520 Westheimer Rd', 'Houston, TX 77006']},
#    'phone': '+17138078857',
#    'display_phone': '(713) 807-8857',
#    'distance': 4272.198267297497},
#   {'id': 'O25KGYPfHB1i7hYyWzsaXg',
#    'alias': 'creed-italian-restaurant-and-bar-houston',
#    'name': 'Creed Italian Restaurant & Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sj5Pultmc2hCDQwehUrN7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/creed-italian-restaurant-and-bar-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 67,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 29.736722, 'longitude': -95.59463},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '12126 Westheimer Rd',
#     'address2': 'Ste 98',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77077',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['12126 Westheimer Rd', 'Ste 98', 'Houston, TX 77077']},
#    'phone': '+18323285151',
#    'display_phone': '(832) 328-5151',
#    'distance': 22843.395362731964},
#   {'id': 'nx6OjaEFRQO2kmzChiSPcQ',
#    'alias': 'la-griglia-houston',
#    'name': 'La Griglia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Tv3WWczrDAy2d2t8P7Wjxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-griglia-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 317,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.75356, 'longitude': -95.40889},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '2002 W Gray St',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77019',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['2002 W Gray St', 'Houston, TX 77019']},
#    'phone': '+17135264700',
#    'display_phone': '(713) 526-4700',
#    'distance': 4818.052459102524},
#   {'id': 'liQTbRIdH1nnqztGj2bnzg',
#    'alias': 'corellis-italian-cafe-houston',
#    'name': "Corelli's Italian Cafe",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JGpSa96WaNgY5rWYGn1Zaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/corellis-italian-cafe-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 117,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.7380757, 'longitude': -95.4752726},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '5640 Westheimer Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77056',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['5640 Westheimer Rd', 'Houston, TX 77056']},
#    'phone': '+17136294424',
#    'display_phone': '(713) 629-4424',
#    'distance': 11497.311039889375},
#   {'id': 'GJwqAynHNqaEm4pixA9meA',
#    'alias': 'piatto-ristorante-houston',
#    'name': 'Piatto Ristorante',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UuEF_UgIKXQ7qA_KMkRCZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piatto-ristorante-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 122,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 29.737821, 'longitude': -95.459841},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4925 W Alabama St',
#     'address2': '',
#     'address3': '',
#     'city': 'Houston',
#     'zip_code': '77056',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['4925 W Alabama St', 'Houston, TX 77056']},
#    'phone': '+17138719722',
#    'display_phone': '(713) 871-9722',
#    'distance': 10041.91405105497},
#   {'id': 'VqPzcZQsr8HwmHPxbL5KCQ',
#    'alias': 'b-b-italia-houston-4',
#    'name': 'B.B. Italia',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Hc5pagZNw61DtUXb8pbMAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b-b-italia-houston-4?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#    'review_count': 71,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 29.77132, 'longitude': -95.61263},
#    'transactions': [],
#    'location': {'address1': '14795 Memorial Dr',
#     'address2': '',
#     'address3': None,
#     'city': 'Houston',
#     'zip_code': '77079',
#     'country': 'US',
#     'state': 'TX',
#     'display_address': ['14795 Memorial Dr', 'Houston, TX 77079']},
#    'phone': '+12815310696',
#    'display_phone': '(281) 531-0696',
#    'distance': 24392.55480254122}],
#  'total': 1400,
#  'region': {'center': {'longitude': -95.35995483398438,
#    'latitude': 29.763025675716687}}}

# %%
len(req.json()["businesses"])
# Out:
# 50

# %%
req.json()["businesses"]
# Out:
# [{'id': 'd6cm5ns_Hfy83-e3nm3CSg',
#   'alias': 'rivas-italian-restaurant-houston',
#   'name': "Riva's Italian Restaurant",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i-0pXB2oDMCetLeDiqNySg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rivas-italian-restaurant-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 508,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.74605, 'longitude': -95.39248},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1117 Missouri St',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77006',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1117 Missouri St', 'Houston, TX 77006']},
#   'phone': '+17135293450',
#   'display_phone': '(713) 529-3450',
#   'distance': 3668.962694214326},
#  {'id': 'x4WealiPVG-tzwzhe7nvpw',
#   'alias': 'north-italia-houston',
#   'name': 'North Italia',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dsUzts2x9Ee9a_hjAbDzlw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/north-italia-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 1500,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.7485868638914,
#    'longitude': -95.4620253208921},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1700 Post Oak Blvd',
#    'address2': 'Ste 190',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77056',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1700 Post Oak Blvd', 'Ste 190', 'Houston, TX 77056']},
#   'phone': '+12816054030',
#   'display_phone': '(281) 605-4030',
#   'distance': 9983.179390848347},
#  {'id': 'McwaN30rgpfIpyDPT913Vw',
#   'alias': 'fabios-artisan-pasta-houston',
#   'name': "Fabio's Artisan Pasta",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UL5j4JwdiZWek6ho0gFl5w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fabios-artisan-pasta-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 244,
#   'categories': [{'alias': 'pastashops', 'title': 'Pasta Shops'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 29.73823, 'longitude': -95.41208},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2129 W Alabama St',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77098',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2129 W Alabama St', 'Houston, TX 77098']},
#   'phone': '+17135281329',
#   'display_phone': '(713) 528-1329',
#   'distance': 5740.851256560756},
#  {'id': 'gid41dFmk4cnSsy2OeJzEQ',
#   'alias': 'roma-houston',
#   'name': 'Roma',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZVHEkng8PAUf8rqGDTQDGA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/roma-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 66,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.7149, 'longitude': -95.41475},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2347 University Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Houston',
#    'zip_code': '77005',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2347 University Blvd', 'Houston, TX 77005']},
#   'phone': '+17136647581',
#   'display_phone': '(713) 664-7581',
#   'distance': 7521.471373663317},
#  {'id': 'z0sbzv4MRstpyodVBjCLLA',
#   'alias': 'coltivare-houston',
#   'name': 'Coltivare',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uTmBUm-ykxkXGFSG5rcJgw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/coltivare-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 815,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.7817, 'longitude': -95.39371},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3320 White Oak Dr',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77007',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3320 White Oak Dr', 'Houston, TX 77007']},
#   'phone': '+17136374095',
#   'display_phone': '(713) 637-4095',
#   'distance': 3863.439668367201},
#  {'id': '8ZhYOX0zREv0Px2aBqnLNg',
#   'alias': 'mia-bella-trattoria-houston-14',
#   'name': 'Mia Bella Trattoria',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7i_Om_o5DIKUUDblkjp1Eg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mia-bella-trattoria-houston-14?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 352,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.7323697055943,
#    'longitude': -95.4381511442779},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3773 Richmond Ave',
#    'address2': 'Ste 1A',
#    'address3': None,
#    'city': 'Houston',
#    'zip_code': '77046',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3773 Richmond Ave', 'Ste 1A', 'Houston, TX 77046']},
#   'phone': '+17133937340',
#   'display_phone': '(713) 393-7340',
#   'distance': 8283.11301121304},
#  {'id': 'yTnMkgBS19T90hxWOEOy4A',
#   'alias': 'potente-houston',
#   'name': 'Potente',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/43_PXR28bztszl17c8aqFw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/potente-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 197,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.7572378866031,
#    'longitude': -95.3574474900742},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '1515 Texas Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77002',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1515 Texas Ave', 'Houston, TX 77002']},
#   'phone': '+17132371515',
#   'display_phone': '(713) 237-1515',
#   'distance': 687.5788988102834},
#  {'id': 'CoonE0BMUPRGHqXWj-XzxQ',
#   'alias': 'lomontes-italian-restaurant-and-bar-houston',
#   'name': "Lomonte's Italian Restaurant and Bar",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Zm6mZ9Tbdyn12YH3bR0vuQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lomontes-italian-restaurant-and-bar-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 172,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.7827472686768, 'longitude': -95.642463684082},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '14510 Grisby Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77079',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['14510 Grisby Rd', 'Houston, TX 77079']},
#   'phone': '+12814960030',
#   'display_phone': '(281) 496-0030',
#   'distance': 27347.798690425236},
#  {'id': 'xRfw_M1BdMpnEzMcFCY_7g',
#   'alias': 'perbacco-houston',
#   'name': 'Perbacco',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4IKxkwbpZ5enzKkWG-1v4g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/perbacco-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 166,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.760168, 'longitude': -95.365059},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '700 Milam St',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77002',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['700 Milam St', 'Houston, TX 77002']},
#   'phone': '+17132242422',
#   'display_phone': '(713) 224-2422',
#   'distance': 586.2755486167018},
#  {'id': 'MXLhzFh9WK0ig3MYt5THDA',
#   'alias': 'grotto-downtown-houston',
#   'name': 'Grotto Downtown',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SLpcg8B8EVQy2RYuwly_Rw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/grotto-downtown-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 317,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.7539178, 'longitude': -95.3571966},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1001 Avenida De Las Americas',
#    'address2': 'Ste A',
#    'address3': None,
#    'city': 'Houston',
#    'zip_code': '77010',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1001 Avenida De Las Americas',
#     'Ste A',
#     'Houston, TX 77010']},
#   'phone': '+17136580752',
#   'display_phone': '(713) 658-0752',
#   'distance': 1047.1634280320973},
#  {'id': 'm-2gMLGy4vIufoL6QNy0tA',
#   'alias': 'giacomos-cibo-e-vino-houston',
#   'name': "Giacomo's Cibo e Vino",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ru_kIYaO3h5saIReja2OyQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/giacomos-cibo-e-vino-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 497,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.742032, 'longitude': -95.423718},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3215 Westheimer Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77098',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3215 Westheimer Rd', 'Houston, TX 77098']},
#   'phone': '+17135221934',
#   'display_phone': '(713) 522-1934',
#   'distance': 6583.267811896613},
#  {'id': 'SYnPb42JQ1zhERBEGg0sGg',
#   'alias': 'patrenellas-houston',
#   'name': "Patrenella's",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iHgX93CCgM3Uba3NrSe5cg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/patrenellas-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 346,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.76912, 'longitude': -95.4021},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '813 Jackson Hill St',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77007',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['813 Jackson Hill St', 'Houston, TX 77007']},
#   'phone': '+17138638223',
#   'display_phone': '(713) 863-8223',
#   'distance': 4122.1756837785115},
#  {'id': '0wemURLMYj9YkkXJI2aS6w',
#   'alias': 'paulies-houston',
#   'name': "Paulie's",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vJfIhDcLieMU2RCDakbCyA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/paulies-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 773,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.7428749, 'longitude': -95.4064275},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1834 Westheimer Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77098',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1834 Westheimer Rd', 'Houston, TX 77098']},
#   'phone': '+17138077271',
#   'display_phone': '(713) 807-7271',
#   'distance': 4986.074028178806},
#  {'id': 'm15OdfXB2MFz_wdshwoGUA',
#   'alias': 'amalfi-ristorante-italiano-and-bar-houston',
#   'name': 'Amalfi Ristorante Italiano & Bar',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hDjLC1TCui2eotSDltjRUQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/amalfi-ristorante-italiano-and-bar-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 179,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.7389991526496,
#    'longitude': -95.4903902865082},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$$',
#   'location': {'address1': '6100 Westheimer Rd',
#    'address2': 'Ste 140',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77057',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['6100 Westheimer Rd', 'Ste 140', 'Houston, TX 77057']},
#   'phone': '+17135322201',
#   'display_phone': '(713) 532-2201',
#   'distance': 12872.303065818098},
#  {'id': 'zYymsWEVEy02KA2KES1faw',
#   'alias': 'antica-osteria-houston',
#   'name': 'Antica Osteria',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Our8CvTt5I0CK4VmBhvwLw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/antica-osteria-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 310,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.725282, 'longitude': -95.413276},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '2311 Bissonnet St',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77005',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2311 Bissonnet St', 'Houston, TX 77005']},
#   'phone': '+17135211155',
#   'display_phone': '(713) 521-1155',
#   'distance': 6650.585570400708},
#  {'id': 'OYiE24uzI_YKGuchV8xo0Q',
#   'alias': 'piola-houston-7',
#   'name': 'Piola',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lA_bymUX7rw8NkaWySN8-A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/piola-houston-7?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 580,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.74287233551, 'longitude': -95.3798845184326},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '3201 Louisiana St',
#    'address2': 'Ste 103',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77006',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3201 Louisiana St', 'Ste 103', 'Houston, TX 77006']},
#   'phone': '+17135248222',
#   'display_phone': '(713) 524-8222',
#   'distance': 2953.5375004870257},
#  {'id': '1oPxBD7nBPa8I6ZCeX1Svg',
#   'alias': 'damians-cucina-italiana-houston-2',
#   'name': "Damian's Cucina Italiana",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/orJx9X2KZr_06svB_gKH9w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/damians-cucina-italiana-houston-2?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 211,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.74437, 'longitude': -95.3797},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '3011 Smith St',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77006',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3011 Smith St', 'Houston, TX 77006']},
#   'phone': '+17135220439',
#   'display_phone': '(713) 522-0439',
#   'distance': 2818.0064561572626},
#  {'id': 'z1J0lVDuy7X7g9Xeha3jKg',
#   'alias': 'd-amicos-italian-market-cafe-houston',
#   'name': "D'Amico's Italian Market Cafe",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6ef3pwmPHDJPlIdxGigFUw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/d-amicos-italian-market-cafe-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 356,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.71598, 'longitude': -95.4153504},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '5510 Morningside Dr',
#    'address2': 'Ste 140',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77005',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['5510 Morningside Dr', 'Ste 140', 'Houston, TX 77005']},
#   'phone': '+17135263400',
#   'display_phone': '(713) 526-3400',
#   'distance': 7481.392282281001},
#  {'id': 'KDkl-gEvbOyEYzuI6JNAlA',
#   'alias': 'mandolas-deli-houston',
#   'name': "Mandola's Deli",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZPLNAtBYjGy2Joni1poyvQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mandolas-deli-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 269,
#   'categories': [{'alias': 'delis', 'title': 'Delis'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.73764, 'longitude': -95.33956},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '4105 Leeland St',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77023',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['4105 Leeland St', 'Houston, TX 77023']},
#   'phone': '+17132235186',
#   'display_phone': '(713) 223-5186',
#   'distance': 3458.0852592453975},
#  {'id': 'yCxdQ2cmsL9k7ktP9g5s4w',
#   'alias': 'bellissimo-ristorante-houston-2',
#   'name': 'Bellissimo Ristorante',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/w-Ip8KSDIDasw2AFn9lUlQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bellissimo-ristorante-houston-2?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 209,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.804596, 'longitude': -95.381574},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1848 Airline Dr',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77009',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1848 Airline Dr', 'Houston, TX 77009']},
#   'phone': '+18326181168',
#   'display_phone': '(832) 618-1168',
#   'distance': 5071.45470534417},
#  {'id': 'KJQu5oYl_x96aP4GLfWTgw',
#   'alias': 'dolce-vita-houston',
#   'name': 'Dolce Vita',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ItTAK5MvCwvdAlvATU8pEQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dolce-vita-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 712,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.744775, 'longitude': -95.38742},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '500 Westheimer Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77006',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['500 Westheimer Rd', 'Houston, TX 77006']},
#   'phone': '+17135208222',
#   'display_phone': '(713) 520-8222',
#   'distance': 3340.9698648875833},
#  {'id': 'XPdL-df73m-sYrTndOrb3Q',
#   'alias': 'osso-and-kristalla-houston-2',
#   'name': 'Osso & Kristalla',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hCLkoyHtaMh1uubxwkdn9A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/osso-and-kristalla-houston-2?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 234,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.7574509, 'longitude': -95.3579026},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1515 Texas Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Houston',
#    'zip_code': '77002',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1515 Texas Ave', 'Houston, TX 77002']},
#   'phone': '+17132216666',
#   'display_phone': '(713) 221-6666',
#   'distance': 650.7708380567746},
#  {'id': '2uSi_8-xouauhoWadGFJfQ',
#   'alias': 'roccos-houston',
#   'name': "Rocco's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/obug8WIcSwbyldgDZ0jRXw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/roccos-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 55,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.79333, 'longitude': -95.35928},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '811 Collingsworth St',
#    'address2': None,
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77009',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['811 Collingsworth St', 'Houston, TX 77009']},
#   'phone': '+17133802700',
#   'display_phone': '(713) 380-2700',
#   'distance': 3371.9606766988},
#  {'id': '6eiWLIo58e4q1pOt_p6FXQ',
#   'alias': 'sorrento-ristorante-italiano-houston',
#   'name': 'Sorrento Ristorante Italiano',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mvyG964EuhJ7MMUkWlkjrw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sorrento-ristorante-italiano-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 302,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.7444128, 'longitude': -95.3867141},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '415 Westheimer Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77006',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['415 Westheimer Rd', 'Houston, TX 77006']},
#   'phone': '+17135270609',
#   'display_phone': '(713) 527-0609',
#   'distance': 3332.9312824588856},
#  {'id': '_4O57SAgWtUafcBT4ruWSw',
#   'alias': 'grazia-italian-kitchen-pearland',
#   'name': 'Grazia Italian Kitchen',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ikFXUFRYl2rixdBCzdGwTw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/grazia-italian-kitchen-pearland?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 756,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.5590781202424,
#    'longitude': -95.3657707648061},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '9415 Broadway',
#    'address2': 'Ste 103',
#    'address3': '',
#    'city': 'Pearland',
#    'zip_code': '77584',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['9415 Broadway', 'Ste 103', 'Pearland, TX 77584']},
#   'phone': '+18322308873',
#   'display_phone': '(832) 230-8873',
#   'distance': 22684.870006518682},
#  {'id': '0gvTBshm7gAq0sB53H-z0g',
#   'alias': 'carrabbas-the-original-on-kirby-houston-2',
#   'name': "Carrabba's - The Original on Kirby",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/z1brhVqR53bV_yC2YDjghQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/carrabbas-the-original-on-kirby-houston-2?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 442,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.7364881579311,
#    'longitude': -95.4183509045328},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3115 Kirby Dr',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77098',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3115 Kirby Dr', 'Houston, TX 77098']},
#   'phone': '+17135223131',
#   'display_phone': '(713) 522-3131',
#   'distance': 6363.1037974552655},
#  {'id': 'sQz8sc02VCw9yCEGwAGgPA',
#   'alias': 'georges-pastaria-houston',
#   'name': "George's Pastaria",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EE0TDBwqlz62IAVyX_XtEA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/georges-pastaria-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 231,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.74936, 'longitude': -95.60649},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1722 S Dairy Ashford St',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77077',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1722 S Dairy Ashford St', 'Houston, TX 77077']},
#   'phone': '+12815581717',
#   'display_phone': '(281) 558-1717',
#   'distance': 23855.524074164405},
#  {'id': 'YkB4ZffQBnpEljGZAX7xFA',
#   'alias': 'mia-bella-trattoria-houston-13',
#   'name': 'Mia Bella Trattoria',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wU1Yn3-7JfKhGNst47-Vpw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mia-bella-trattoria-houston-13?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 279,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.7534684960069,
#    'longitude': -95.3641167312134},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1201 Caroline St',
#    'address2': 'Ste 161',
#    'address3': None,
#    'city': 'Houston',
#    'zip_code': '77002',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1201 Caroline St', 'Ste 161', 'Houston, TX 77002']},
#   'phone': '+18323196675',
#   'display_phone': '(832) 319-6675',
#   'distance': 1136.1141742819455},
#  {'id': 'X8pydxs5EFUSwKDmhJCCEw',
#   'alias': 'grazia-italian-kitchen-houston',
#   'name': 'Grazia Italian Kitchen',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/e4HBKO3bqAYAWp1DUa5GUg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/grazia-italian-kitchen-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 229,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.5777702331543,
#    'longitude': -95.1404571533203},
#   'transactions': ['restaurant_reservation', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1001 Pineloch Dr',
#    'address2': 'Ste 1100',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77062',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1001 Pineloch Dr', 'Ste 1100', 'Houston, TX 77062']},
#   'phone': '+12814862083',
#   'display_phone': '(281) 486-2083',
#   'distance': 29556.687072125613},
#  {'id': '8dkNhXi6vPkZDgq7T0-xhg',
#   'alias': 'postino-montrose-houston-2',
#   'name': 'Postino Montrose',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5ZIrVBqRis7Y7lt-ZkCngg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/postino-montrose-houston-2?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 9,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 29.74651, 'longitude': -95.39033},
#   'transactions': [],
#   'location': {'address1': '805 Pacific St',
#    'address2': '',
#    'address3': None,
#    'city': 'Houston',
#    'zip_code': '77006',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['805 Pacific St', 'Houston, TX 77006']},
#   'phone': '+17133886767',
#   'display_phone': '(713) 388-6767',
#   'distance': 3455.361143026402},
#  {'id': 'vVxrh4Jf6Cq_-PKg8YObFg',
#   'alias': 'cavatore-italian-restaurant-houston',
#   'name': 'Cavatore Italian Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hAS92RXwkxQlZgDWW4FsFw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cavatore-italian-restaurant-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 338,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 29.8052, 'longitude': -95.42883},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '2120 Ella Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77008',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2120 Ella Blvd', 'Houston, TX 77008']},
#   'phone': '+17138696622',
#   'display_phone': '(713) 869-6622',
#   'distance': 8120.842538541184},
#  {'id': 'QrrOqwS-oXJ3-CRQdusfBg',
#   'alias': 'boh-pasta-and-pizza-houston',
#   'name': 'BOH Pasta & Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2HSh_DRwZ3hLp0UGZsnplg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/boh-pasta-and-pizza-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 26,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.7617656683504,
#    'longitude': -95.3621810104161},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '409 Travis St',
#    'address2': None,
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77002',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['409 Travis St', 'Houston, TX 77002']},
#   'phone': '+17133645502',
#   'display_phone': '(713) 364-5502',
#   'distance': 256.52692447637577},
#  {'id': 'QxzCY8B1N_XuIuUl-UanUA',
#   'alias': 'bollo-woodfired-pizza-houston',
#   'name': 'Bollo Woodfired Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KwuCTyhZQJMvW2-fiqT7TQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bollo-woodfired-pizza-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 569,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.7389786, 'longitude': -95.4134581},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2202 W Alabama St',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77098',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2202 W Alabama St', 'Houston, TX 77098']},
#   'phone': '+17136770391',
#   'display_phone': '(713) 677-0391',
#   'distance': 5816.198148890635},
#  {'id': 'ayPSl6UmabxlEXeHX8Fisw',
#   'alias': 'postino-heights-houston-3',
#   'name': 'Postino Heights',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YXZclCARt6Xj_oQPtlQHrQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/postino-heights-houston-3?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 387,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.78306, 'longitude': -95.3985299},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '642 Yale St',
#    'address2': 'Ste A',
#    'address3': None,
#    'city': 'Houston',
#    'zip_code': '77007',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['642 Yale St', 'Ste A', 'Houston, TX 77007']},
#   'phone': '+13462231111',
#   'display_phone': '(346) 223-1111',
#   'distance': 4333.948852417317},
#  {'id': '8tk2n3wdXX3oq8lryKfeig',
#   'alias': 'frenchies-houston-3',
#   'name': "Frenchie's",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BxptVhCwFrNF0RiXnq9Xmg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/frenchies-houston-3?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 271,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.5463748, 'longitude': -95.1058725},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1041 Nasa Pkwy',
#    'address2': None,
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77058',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1041 Nasa Pkwy', 'Houston, TX 77058']},
#   'phone': '+12814867144',
#   'display_phone': '(281) 486-7144',
#   'distance': 34391.835822245426},
#  {'id': 'ZkM_qfaCNWRCb0vb3T813g',
#   'alias': 'fresco-cafe-italiano-houston',
#   'name': 'Fresco Cafe Italiano',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WVxRS5Tf4PoFr2v7AlOY1Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fresco-cafe-italiano-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 170,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pastashops', 'title': 'Pasta Shops'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.7287262957213,
#    'longitude': -95.4316117488783},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3277 Southwest Fwy',
#    'address2': 'Ste A',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77027',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3277 Southwest Fwy', 'Ste A', 'Houston, TX 77027']},
#   'phone': '+12818882226',
#   'display_phone': '(281) 888-2226',
#   'distance': 7899.648765803011},
#  {'id': 'hBDyMM7g3Gy3ucKgLPUvZg',
#   'alias': 'adriatic-cafe-italian-grill-jersey-village',
#   'name': 'Adriatic Cafe  Italian Grill',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/oz5rZdxkq3ONgqorfL6Suw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/adriatic-cafe-italian-grill-jersey-village?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 521,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.8898572957493,
#    'longitude': -95.5826705374774},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '17402 Northwest Fwy',
#    'address2': None,
#    'address3': '',
#    'city': 'Jersey Village',
#    'zip_code': '77040',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['17402 Northwest Fwy', 'Jersey Village, TX 77040']},
#   'phone': '+17139836565',
#   'display_phone': '(713) 983-6565',
#   'distance': 25699.67299989509},
#  {'id': '52D7I26xY3t9uz0HgCBeGQ',
#   'alias': 'piada-italian-street-food-houston-2',
#   'name': 'Piada Italian Street Food',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fexn75FnuH5A6Ai3Jgsxqw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/piada-italian-street-food-houston-2?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 362,
#   'categories': [{'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.76099, 'longitude': -95.42052},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '5801 Memorial Dr',
#    'address2': 'Ste E',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77007',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['5801 Memorial Dr', 'Ste E', 'Houston, TX 77007']},
#   'phone': '+18328346415',
#   'display_phone': '(832) 834-6415',
#   'distance': 5841.586159494749},
#  {'id': 'bY7wa6sfVb7MKsxq8_pcVw',
#   'alias': 'vinoteca-poscol-houston-3',
#   'name': 'Vinoteca Poscol',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/R8BTqoTCcz_t4ZculR7GGg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/vinoteca-poscol-houston-3?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 117,
#   'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.74476, 'longitude': -95.3893499},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '608 Westheimer Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77006',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['608 Westheimer Rd', 'Houston, TX 77006']},
#   'phone': '+17135292797',
#   'display_phone': '(713) 529-2797',
#   'distance': 3485.306811663798},
#  {'id': 'N4TDKKat3ADCTWPGVmiEOA',
#   'alias': 'mina-ristorante-houston-2',
#   'name': 'Mina Ristorante',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WiG9IX6-HaHQXPyrGdD3Ug/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mina-ristorante-houston-2?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 9,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.7381940494014,
#    'longitude': -95.4363139242039},
#   'transactions': [],
#   'location': {'address1': '3641 W Alabama St',
#    'address2': '',
#    'address3': None,
#    'city': 'Houston',
#    'zip_code': '77027',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3641 W Alabama St', 'Houston, TX 77027']},
#   'phone': '+18329402126',
#   'display_phone': '(832) 940-2126',
#   'distance': 7871.748562723768},
#  {'id': '-HLVm44tvKu2V31lz6VQaA',
#   'alias': 'maggianos-little-italy-houston',
#   'name': "Maggiano's Little Italy",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zwcGxO0AYTd_HHNrG-kS5Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/maggianos-little-italy-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 630,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 29.74507, 'longitude': -95.460509},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '2019 Post Oak Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77056',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2019 Post Oak Blvd', 'Houston, TX 77056']},
#   'phone': '+17139612700',
#   'display_phone': '(713) 961-2700',
#   'distance': 9910.23091617366},
#  {'id': '_WpiWEiXec2HsBaCDemq9Q',
#   'alias': 'lomontes-italian-restaurant-and-pizzeria-richmond-3',
#   'name': "Lomonte's Italian Restaurant & Pizzeria",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5IKnas3HO01fY-mIROd2YQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lomontes-italian-restaurant-and-pizzeria-richmond-3?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 265,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.62409, 'longitude': -95.71922},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '815 Plantation Dr',
#    'address2': 'Ste 180',
#    'address3': '',
#    'city': 'Richmond',
#    'zip_code': '77406',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['815 Plantation Dr', 'Ste 180', 'Richmond, TX 77406']},
#   'phone': '+12812328290',
#   'display_phone': '(281) 232-8290',
#   'distance': 37844.43965855639},
#  {'id': 'Eww0CBzbPPPAqVeLnKj5Pg',
#   'alias': 'spaghetti-western-italian-cafe-houston',
#   'name': 'Spaghetti Western Italian Cafe',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/43lWTm3vMhMT-yckN3H6EQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/spaghetti-western-italian-cafe-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 274,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.775061, 'longitude': -95.409362},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1608 Shepherd Dr',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77007',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1608 Shepherd Dr', 'Houston, TX 77007']},
#   'phone': '+17138611313',
#   'display_phone': '(713) 861-1313',
#   'distance': 4953.040992892985},
#  {'id': 'fZsyLhNQ0GvtKFzCKxS7Yg',
#   'alias': 'crisp-houston-2',
#   'name': 'Crisp',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r3VXcR8lruk7-fTWQTcJwQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/crisp-houston-2?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 845,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.8062839508057,
#    'longitude': -95.4220886230469},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2220 Bevis St',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77008',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2220 Bevis St', 'Houston, TX 77008']},
#   'phone': '+17133600222',
#   'display_phone': '(713) 360-0222',
#   'distance': 7687.150562772566},
#  {'id': 'ns0zrAgnlOmBh-AQUapBxg',
#   'alias': 'da-marco-houston',
#   'name': 'Da Marco',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/k_0tX6Bg1zwkoSOJzmc40w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/da-marco-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 324,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.74313, 'longitude': -95.397814},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '1520 Westheimer Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77006',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1520 Westheimer Rd', 'Houston, TX 77006']},
#   'phone': '+17138078857',
#   'display_phone': '(713) 807-8857',
#   'distance': 4272.198267297497},
#  {'id': 'O25KGYPfHB1i7hYyWzsaXg',
#   'alias': 'creed-italian-restaurant-and-bar-houston',
#   'name': 'Creed Italian Restaurant & Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sj5Pultmc2hCDQwehUrN7g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/creed-italian-restaurant-and-bar-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 67,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.736722, 'longitude': -95.59463},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '12126 Westheimer Rd',
#    'address2': 'Ste 98',
#    'address3': None,
#    'city': 'Houston',
#    'zip_code': '77077',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['12126 Westheimer Rd', 'Ste 98', 'Houston, TX 77077']},
#   'phone': '+18323285151',
#   'display_phone': '(832) 328-5151',
#   'distance': 22843.395362731964},
#  {'id': 'nx6OjaEFRQO2kmzChiSPcQ',
#   'alias': 'la-griglia-houston',
#   'name': 'La Griglia',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Tv3WWczrDAy2d2t8P7Wjxw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-griglia-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 317,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.75356, 'longitude': -95.40889},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '2002 W Gray St',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77019',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2002 W Gray St', 'Houston, TX 77019']},
#   'phone': '+17135264700',
#   'display_phone': '(713) 526-4700',
#   'distance': 4818.052459102524},
#  {'id': 'liQTbRIdH1nnqztGj2bnzg',
#   'alias': 'corellis-italian-cafe-houston',
#   'name': "Corelli's Italian Cafe",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JGpSa96WaNgY5rWYGn1Zaw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/corellis-italian-cafe-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 117,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.7380757, 'longitude': -95.4752726},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '5640 Westheimer Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77056',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['5640 Westheimer Rd', 'Houston, TX 77056']},
#   'phone': '+17136294424',
#   'display_phone': '(713) 629-4424',
#   'distance': 11497.311039889375},
#  {'id': 'GJwqAynHNqaEm4pixA9meA',
#   'alias': 'piatto-ristorante-houston',
#   'name': 'Piatto Ristorante',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UuEF_UgIKXQ7qA_KMkRCZA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/piatto-ristorante-houston?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 122,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.737821, 'longitude': -95.459841},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '4925 W Alabama St',
#    'address2': '',
#    'address3': '',
#    'city': 'Houston',
#    'zip_code': '77056',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['4925 W Alabama St', 'Houston, TX 77056']},
#   'phone': '+17138719722',
#   'display_phone': '(713) 871-9722',
#   'distance': 10041.91405105497},
#  {'id': 'VqPzcZQsr8HwmHPxbL5KCQ',
#   'alias': 'b-b-italia-houston-4',
#   'name': 'B.B. Italia',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Hc5pagZNw61DtUXb8pbMAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/b-b-italia-houston-4?adjust_creative=oOYEY2fFk9QNeRkdw6v4dw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oOYEY2fFk9QNeRkdw6v4dw',
#   'review_count': 71,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 29.77132, 'longitude': -95.61263},
#   'transactions': [],
#   'location': {'address1': '14795 Memorial Dr',
#    'address2': '',
#    'address3': None,
#    'city': 'Houston',
#    'zip_code': '77079',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['14795 Memorial Dr', 'Houston, TX 77079']},
#   'phone': '+12815310696',
#   'display_phone': '(281) 531-0696',
#   'distance': 24392.55480254122}]

# %%
keylist = req.json().keys()

# %%
keylist
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
df = pd.DataFrame.from_dict(json_normalize(req.json()["businesses"]), orient='columns')

# %%
df_data = df[['coordinates.latitude','coordinates.longitude','location.display_address','name','price','rating','review_count']]

# %%
df_data = df_data.sort_values(by='rating', ascending=False)

# %%
df_data = df_data.reset_index()

# %%
np.mean(df_data["rating"])
# Out:
# 4.1

# %% [markdown]
# ## Normalizing the data
# ### Using Bayesian Average Ratings to normalize the rating variable in accordance with the number of votes. This is the Weighted Rating(WR). (Imdb uses this to normalize their movie ratings and we will follow a similar model)
#
# ## ``` weighted rating (WR) = (v ÷ (v+m)) × R + (m ÷ (v+m)) × C```
#
# where:
#
# R = average rating for the restaurent -> ```df_data["rating"]```
#
# v = number of votes for the restaurent -> ```df_data["review_count"]```
#
# m = minimum votes required to be listed in this mode ```(We will select 100 for this model) -> min_votes```
#
# C = the mean rating across the whole dataset -> ```np.mean(df_data["rating"])```

# %%
min_votes = 50
df_data["wr"] = (df_data["review_count"] / (df_data["review_count"] + min_votes)) * df_data["rating"] + (np.mean(df_data["rating"]) / (df_data["review_count"] + min_votes))

df_data.head(50)
# Out:
#     index  coordinates.latitude  coordinates.longitude  \
# 0       2             29.738230             -95.412080
# 1      29             29.746510             -95.390330
# 2      36             29.889857             -95.582671
# 3      31             29.761766             -95.362181
# 4       5             29.732370             -95.438151
# 5       6             29.757238             -95.357447
# 6      22             29.793330             -95.359280
# 7      45             29.736722             -95.594630
# 8      41             29.624090             -95.719220
# 9      18             29.737640             -95.339560
# 10     35             29.728726             -95.431612
# 11      0             29.746050             -95.392480
# 12     32             29.738979             -95.413458
# 13     33             29.783060             -95.398530
# 14     34             29.546375             -95.105873
# 15     39             29.738194             -95.436314
# 16     37             29.760990             -95.420520
# 17     38             29.744760             -95.389350
# 18     27             29.753468             -95.364117
# 19     42             29.775061             -95.409362
# 20     43             29.806284             -95.422089
# 21     44             29.743130             -95.397814
# 22     46             29.753560             -95.408890
# 23     47             29.738076             -95.475273
# 24     48             29.737821             -95.459841
# 25     28             29.577770             -95.140457
# 26     25             29.736488             -95.418351
# 27     26             29.749360             -95.606490
# 28      1             29.748587             -95.462025
# 29      3             29.714900             -95.414750
# 30      4             29.781700             -95.393710
# 31      7             29.782747             -95.642464
# 32      8             29.760168             -95.365059
# 33      9             29.753918             -95.357197
# 34     10             29.742032             -95.423718
# 35     11             29.769120             -95.402100
# 36     12             29.742875             -95.406428
# 37     13             29.738999             -95.490390
# 38     14             29.725282             -95.413276
# 39     15             29.742872             -95.379885
# 40     16             29.744370             -95.379700
# 41     17             29.715980             -95.415350
# 42     19             29.804596             -95.381574
# 43     20             29.744775             -95.387420
# 44     21             29.757451             -95.357903
# 45     23             29.744413             -95.386714
# 46     24             29.559078             -95.365771
# 47     40             29.745070             -95.460509
# 48     30             29.805200             -95.428830
# 49     49             29.771320             -95.612630
#
#                              location.display_address  \
# 0              [2129 W Alabama St, Houston, TX 77098]
# 1                 [805 Pacific St, Houston, TX 77006]
# 2     [17402 Northwest Fwy, Jersey Village, TX 77040]
# 3                  [409 Travis St, Houston, TX 77002]
# 4      [3773 Richmond Ave, Ste 1A, Houston, TX 77046]
# 5                 [1515 Texas Ave, Houston, TX 77002]
# 6           [811 Collingsworth St, Houston, TX 77009]
# 7    [12126 Westheimer Rd, Ste 98, Houston, TX 77077]
# 8    [815 Plantation Dr, Ste 180, Richmond, TX 77406]
# 9                [4105 Leeland St, Houston, TX 77023]
# 10     [3277 Southwest Fwy, Ste A, Houston, TX 77027]
# 11              [1117 Missouri St, Houston, TX 77006]
# 12             [2202 W Alabama St, Houston, TX 77098]
# 13            [642 Yale St, Ste A, Houston, TX 77007]
# 14                [1041 Nasa Pkwy, Houston, TX 77058]
# 15             [3641 W Alabama St, Houston, TX 77027]
# 16       [5801 Memorial Dr, Ste E, Houston, TX 77007]
# 17             [608 Westheimer Rd, Houston, TX 77006]
# 18     [1201 Caroline St, Ste 161, Houston, TX 77002]
# 19              [1608 Shepherd Dr, Houston, TX 77007]
# 20                 [2220 Bevis St, Houston, TX 77008]
# 21            [1520 Westheimer Rd, Houston, TX 77006]
# 22                [2002 W Gray St, Houston, TX 77019]
# 23            [5640 Westheimer Rd, Houston, TX 77056]
# 24             [4925 W Alabama St, Houston, TX 77056]
# 25    [1001 Pineloch Dr, Ste 1100, Houston, TX 77062]
# 26                 [3115 Kirby Dr, Houston, TX 77098]
# 27       [1722 S Dairy Ashford St, Houston, TX 77077]
# 28   [1700 Post Oak Blvd, Ste 190, Houston, TX 77056]
# 29          [2347 University Blvd, Houston, TX 77005]
# 30             [3320 White Oak Dr, Houston, TX 77007]
# 31               [14510 Grisby Rd, Houston, TX 77079]
# 32                  [700 Milam St, Houston, TX 77002]
# 33  [1001 Avenida De Las Americas, Ste A, Houston,...
# 34            [3215 Westheimer Rd, Houston, TX 77098]
# 35           [813 Jackson Hill St, Houston, TX 77007]
# 36            [1834 Westheimer Rd, Houston, TX 77098]
# 37   [6100 Westheimer Rd, Ste 140, Houston, TX 77057]
# 38             [2311 Bissonnet St, Houston, TX 77005]
# 39    [3201 Louisiana St, Ste 103, Houston, TX 77006]
# 40                 [3011 Smith St, Houston, TX 77006]
# 41  [5510 Morningside Dr, Ste 140, Houston, TX 77005]
# 42               [1848 Airline Dr, Houston, TX 77009]
# 43             [500 Westheimer Rd, Houston, TX 77006]
# 44                [1515 Texas Ave, Houston, TX 77002]
# 45             [415 Westheimer Rd, Houston, TX 77006]
# 46       [9415 Broadway, Ste 103, Pearland, TX 77584]
# 47            [2019 Post Oak Blvd, Houston, TX 77056]
# 48                [2120 Ella Blvd, Houston, TX 77008]
# 49             [14795 Memorial Dr, Houston, TX 77079]
#
#                                        name price  rating  review_count  \
# 0                     Fabio's Artisan Pasta    $$     5.0           244
# 1                          Postino Montrose   NaN     5.0             9
# 2              Adriatic Cafe  Italian Grill    $$     4.5           521
# 3                         BOH Pasta & Pizza    $$     4.5            26
# 4                       Mia Bella Trattoria    $$     4.5           352
# 5                                   Potente   $$$     4.5           197
# 6                                   Rocco's    $$     4.5            55
# 7            Creed Italian Restaurant & Bar    $$     4.5            67
# 8   Lomonte's Italian Restaurant & Pizzeria    $$     4.5           265
# 9                            Mandola's Deli     $     4.5           269
# 10                     Fresco Cafe Italiano    $$     4.5           170
# 11                Riva's Italian Restaurant    $$     4.0           508
# 12                    Bollo Woodfired Pizza    $$     4.0           569
# 13                          Postino Heights    $$     4.0           387
# 14                               Frenchie's    $$     4.0           271
# 15                          Mina Ristorante   NaN     4.0             9
# 16                Piada Italian Street Food     $     4.0           362
# 17                          Vinoteca Poscol    $$     4.0           117
# 18                      Mia Bella Trattoria    $$     4.0           279
# 19           Spaghetti Western Italian Cafe    $$     4.0           274
# 20                                    Crisp    $$     4.0           845
# 21                                 Da Marco  $$$$     4.0           324
# 22                               La Griglia   $$$     4.0           317
# 23                   Corelli's Italian Cafe    $$     4.0           117
# 24                        Piatto Ristorante    $$     4.0           122
# 25                   Grazia Italian Kitchen    $$     4.0           229
# 26       Carrabba's - The Original on Kirby    $$     4.0           442
# 27                        George's Pastaria    $$     4.0           231
# 28                             North Italia    $$     4.0          1500
# 29                                     Roma    $$     4.0            66
# 30                                Coltivare    $$     4.0           815
# 31     Lomonte's Italian Restaurant and Bar    $$     4.0           172
# 32                                 Perbacco    $$     4.0           166
# 33                          Grotto Downtown    $$     4.0           317
# 34                    Giacomo's Cibo e Vino    $$     4.0           497
# 35                             Patrenella's    $$     4.0           346
# 36                                 Paulie's    $$     4.0           773
# 37         Amalfi Ristorante Italiano & Bar   $$$     4.0           179
# 38                           Antica Osteria   $$$     4.0           310
# 39                                    Piola    $$     4.0           580
# 40                 Damian's Cucina Italiana   $$$     4.0           211
# 41            D'Amico's Italian Market Cafe    $$     4.0           356
# 42                    Bellissimo Ristorante    $$     4.0           209
# 43                               Dolce Vita    $$     4.0           712
# 44                         Osso & Kristalla    $$     4.0           234
# 45             Sorrento Ristorante Italiano   $$$     4.0           302
# 46                   Grazia Italian Kitchen    $$     4.0           756
# 47                  Maggiano's Little Italy    $$     3.5           630
# 48              Cavatore Italian Restaurant    $$     3.5           338
# 49                              B.B. Italia   NaN     3.5            71
#
#           wr
# 0   4.163605
# 1   0.832203
# 2   4.113135
# 3   1.593421
# 4   3.950498
# 5   3.605668
# 6   2.396190
# 7   2.611966
# 8   3.798730
# 9   3.807524
# 10  3.495909
# 11  3.648925
# 12  3.683522
# 13  3.551716
# 14  3.389720
# 15  0.679661
# 16  3.524515
# 17  2.826946
# 18  3.404559
# 19  3.395370
# 20  3.781117
# 21  3.476203
# 22  3.466213
# 23  2.826946
# 24  2.861047
# 25  3.297849
# 26  3.601829
# 27  3.302847
# 28  3.873613
# 29  2.311207
# 30  3.773526
# 31  3.117568
# 32  3.093056
# 33  3.466213
# 34  3.641865
# 35  3.505303
# 36  3.761968
# 37  3.144541
# 38  3.455833
# 39  3.689048
# 40  3.249425
# 41  3.517488
# 42  3.243629
# 43  3.742913
# 44  3.310211
# 45  3.443466
# 46  3.756948
# 47  3.248676
# 48  3.059536
# 49  2.087603

# %%
df_data = df_data.sort_values(by='wr', ascending=False)
df_data = df_data.reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-513be5677572> in <module>
#       1 df_data = df_data.sort_values(by='wr', ascending=False)
# ----> 2 df_data = df_data.reset_index()
#       3 df_data
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4429                 # to ndarray and maybe infer different dtype
#    4430                 level_values = _maybe_casted_values(lev, lab)
# -> 4431                 new_obj.insert(0, name, level_values)
#    4432
#    4433         new_obj.index = new_index
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3471         value = self._sanitize_column(column, value, broadcast=False)
#    3472         self._data.insert(loc, column, value,
# -> 3473                           allow_duplicates=allow_duplicates)
#    3474
#    3475     def assign(self, **kwargs):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1147         if not allow_duplicates and item in self.items:
#    1148             # Should this be a different kind of error??
# -> 1149             raise ValueError('cannot insert {}, already exists'.format(item))
#    1150
#    1151         if not isinstance(loc, int):
#
# ValueError: cannot insert level_0, already exists

# %%
df_data.tail()
# Out:
#     level_0  index  coordinates.latitude  coordinates.longitude  \
# 45       29      3             29.714900             -95.414750
# 46       49     49             29.771320             -95.612630
# 47        3     31             29.761766             -95.362181
# 48        1     29             29.746510             -95.390330
# 49       15     39             29.738194             -95.436314
#
#                      location.display_address               name price  \
# 45  [2347 University Blvd, Houston, TX 77005]               Roma    $$
# 46     [14795 Memorial Dr, Houston, TX 77079]        B.B. Italia   NaN
# 47         [409 Travis St, Houston, TX 77002]  BOH Pasta & Pizza    $$
# 48        [805 Pacific St, Houston, TX 77006]   Postino Montrose   NaN
# 49     [3641 W Alabama St, Houston, TX 77027]    Mina Ristorante   NaN
#
#     rating  review_count        wr
# 45     4.0            66  2.311207
# 46     3.5            71  2.087603
# 47     4.5            26  1.593421
# 48     5.0             9  0.832203
# 49     4.0             9  0.679661

# %%
df_data.to_csv('pizza_htx.csv')

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager
import matplotlib.style as style
style.use('seaborn-darkgrid')

# Say, "the default sans-serif font is COMIC SANS"
matplotlib.rcParams['font.sans-serif'] = "Krungthep"
# Then, "ALWAYS use sans-serif fonts"
matplotlib.rcParams['font.family'] = "Krungthep"

#rating = [4,3,2,5,2,3,4,2,3,5,4,1,2,3,4]
rating = df_data["wr"]
name = df_data["name"]
colors = ['gray','#D3B186']

row = 0
plt.figure(figsize=(350,350)) 
N = 15 # number of subplots you want
fig, ax1 = plt.subplots(10, 5)
fig.suptitle('Pizza PIE Chart - Houston \n Where to eat Pizza in H-Town?',color="navy", fontsize=54, fontweight='bold')
row = 0
index=0
while row < 10:     # the header for the outer loop
    col = 0
    while col < 5:   # the header for the inner loop
        sizes = [5-rating[index],rating[index]]
        ax1[row,col].pie(sizes,labels=['',''],colors=colors, autopct='',counterclock=False,shadow=True, startangle=90,textprops={'fontsize': 14})
        ax1[row,col].set_title(name[index],fontsize= 12.5,color="navy")
        col+= 1
        index+=1
    

    row+=1
fig = plt.gcf()
fig.set_size_inches(20,30)

fig.text(0.13, 0.915, "Beige Portion",color='#D3B186', fontsize=20)
fig.text(0.2325, 0.915, "indicates the Restaurent Rating, while the",color='Black', fontsize=20)
fig.text(0.551, 0.915, "Gray leftover portion",color='gray', fontsize=20)
fig.text(0.712, 0.915, "indicates the difference",color='black', fontsize=20)
fig.text(0.13, 0.905, "from the maximum possible rating. More slices(in gray) missing, the lower the rating of the restaurent.",color='black', fontsize=20)
plt.savefig('htown_pizza.png', bbox_inches='tight')
plt.show()
